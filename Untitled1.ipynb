# %% [markdown]
# <a href="https://colab.research.google.com/github/Suresh4c5/VITBML-EDA/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ****Indian Premier League(IPL) CRICKET BALL-BY-BALL DATASET****

# %% [markdown]
# **IPL means Indian Premier League ball-by ball data imported from "kaggle.com/datasets"**

# %% [markdown]
# pd-this variable is imported for pandas package....other key wprds are described in the particular cells...we are going to apply pandas operations fpr **analysis**

# %%
import pandas as pd

# %% [markdown]
# **READING DATA**

# %%
# Read data from file
ipl=pd.read_csv('deliveries.csv') 
ipl
# Out:
#        match_id  inning  ... dismissal_kind fielder
# 0             1       1  ...            NaN     NaN
# 1             1       1  ...            NaN     NaN
# 2             1       1  ...            NaN     NaN
# 3             1       1  ...            NaN     NaN
# 4             1       1  ...            NaN     NaN
# ...         ...     ...  ...            ...     ...
# 20538        88       1  ...            NaN     NaN
# 20539        88       1  ...            NaN     NaN
# 20540        88       1  ...            NaN     NaN
# 20541        88       1  ...            NaN     NaN
# 20542        88       1  ...            NaN     NaN
#
# [20543 rows x 21 columns]

# %% [markdown]
# **READING COLOUMNS**

# %%
## .columns gives column names of given data set
print(ipl.columns)                          # colnames() in R - Column Namesprint(list(df.index)[:10])
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# **1.DATA TYPES**

# %%
## .dtypes gives data types for each column
print(ipl.dtypes)                           # str() in R - Data types
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %% [markdown]
# **2.CENTRAL TENDENCY**

# %%
#sorting data
sorted(ipl)
ipl
# Out:
#        match_id  inning  ... dismissal_kind fielder
# 0             1       1  ...            NaN     NaN
# 1             1       1  ...            NaN     NaN
# 2             1       1  ...            NaN     NaN
# 3             1       1  ...            NaN     NaN
# 4             1       1  ...            NaN     NaN
# ...         ...     ...  ...            ...     ...
# 20538        88       1  ...            NaN     NaN
# 20539        88       1  ...            NaN     NaN
# 20540        88       1  ...            NaN     NaN
# 20541        88       1  ...            NaN     NaN
# 20542        88       1  ...            NaN     NaN
#
# [20543 rows x 21 columns]

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
#To find the median of dataset we use median()
ipl.median()
# Out:
# match_id         44.0
# inning            1.0
# over             10.0
# ball              4.0
# is_super_over     0.0
# wide_runs         0.0
# bye_runs          0.0
# legbye_runs       0.0
# noball_runs       0.0
# penalty_runs      0.0
# batsman_runs      1.0
# extra_runs        0.0
# total_runs        1.0
# dtype: float64

# %%
#To find the mode we use dataset we use mode()
ipl.mode()
# Out:
#    match_id  inning    batting_team  ... player_dismissed  dismissal_kind     fielder
# 0        34       1  Mumbai Indians  ...         PA Patel          caught  RV Uthappa
#
# [1 rows x 21 columns]

# %%
#mean for axis=1
ipl.mean(axis=1)
# Out:
# 0        0.307692
# 1        0.384615
# 2        1.076923
# 3        0.538462
# 4        1.076923
#            ...
# 20538    8.692308
# 20539    7.769231
# 20540    8.000000
# 20541    7.923077
# 20542    8.153846
# Length: 20543, dtype: float64

# %% [markdown]
# **3.VARIABILITY**

# %%
# standard deviation
# degree of freedom = 0
# divided by n instead of divided by n - 1
ipl.std(ddof=0)
# Out:
# match_id         25.271483
# inning            0.502251
# over              5.652115
# ball              1.809117
# is_super_over     0.025148
# wide_runs         0.247982
# bye_runs          0.114960
# legbye_runs       0.198030
# noball_runs       0.067144
# penalty_runs      0.034884
# batsman_runs      1.646887
# extra_runs        0.341731
# total_runs        1.632048
# dtype: float64

# %% [markdown]
# **4.ABOUT THE DISTRIBUTION**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
a=ipl.tail(10)
a.plot(kind="bar")
plt.show()

# %%
# Handiling missing values (Dealing with NA)
#Find for NA's
ipl.isna() # to find for NA's in a dataframe
# Out:
#        match_id  inning  ...  dismissal_kind  fielder
# 0         False   False  ...            True     True
# 1         False   False  ...            True     True
# 2         False   False  ...            True     True
# 3         False   False  ...            True     True
# 4         False   False  ...            True     True
# ...         ...     ...  ...             ...      ...
# 20538     False   False  ...            True     True
# 20539     False   False  ...            True     True
# 20540     False   False  ...            True     True
# 20541     False   False  ...            True     True
# 20542     False   False  ...            True     True
#
# [20543 rows x 21 columns]

# %%
8888#Fill NA's with zero in dataset
ipl.fillna(0)
# Out:
#        match_id  inning  ... dismissal_kind fielder
# 0             1       1  ...              0       0
# 1             1       1  ...              0       0
# 2             1       1  ...              0       0
# 3             1       1  ...              0       0
# 4             1       1  ...              0       0
# ...         ...     ...  ...            ...     ...
# 20538        88       1  ...              0       0
# 20539        88       1  ...              0       0
# 20540        88       1  ...              0       0
# 20541        88       1  ...              0       0
# 20542        88       1  ...              0       0
#
# [20543 rows x 21 columns]

# %%
#Fill NA's with previous value in data set
ipl.fillna(method='pad')
# Out:
#        match_id  inning  ... dismissal_kind   fielder
# 0             1       1  ...            NaN       NaN
# 1             1       1  ...            NaN       NaN
# 2             1       1  ...            NaN       NaN
# 3             1       1  ...            NaN       NaN
# 4             1       1  ...            NaN       NaN
# ...         ...     ...  ...            ...       ...
# 20538        88       1  ...        run out  DW Steyn
# 20539        88       1  ...        run out  DW Steyn
# 20540        88       1  ...        run out  DW Steyn
# 20541        88       1  ...        run out  DW Steyn
# 20542        88       1  ...        run out  DW Steyn
#
# [20543 rows x 21 columns]

# %%
#Fill NA's with next values in dataset

ipl.fillna(method ='bfill')
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...         caught  Mandeep Singh
# 1             1       1  ...         caught  Mandeep Singh
# 2             1       1  ...         caught  Mandeep Singh
# 3             1       1  ...         caught  Mandeep Singh
# 4             1       1  ...         caught  Mandeep Singh
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...            NaN            NaN
# 20539        88       1  ...            NaN            NaN
# 20540        88       1  ...            NaN            NaN
# 20541        88       1  ...            NaN            NaN
# 20542        88       1  ...            NaN            NaN
#
# [20543 rows x 21 columns]

# %%
#Fill NA's with a constant/text 
ipl.fillna("Not available",inplace=True) # Note: this will modify any other views on this object
ipl
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %%
#Use interpolate function to fill the missing values which are in data set
ipl.interpolate(method="linear") #‘linear’: ignore the index and treat the values as equally spaced. default
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %%
#Remove rows with NA's in dataset
ipl.dropna() # Drop rows with NA
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %%
#Remove row which contains all NA's

ipl.dropna(how="all") # Drop the rows containing all NA's
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %%
#Remove the columns containing NA's
ipl.dropna(axis=1) # drop columns with NA's
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %%
pd.DataFrame(ipl)
# Out:
#        match_id  inning  ... dismissal_kind        fielder
# 0             1       1  ...  Not available  Not available
# 1             1       1  ...  Not available  Not available
# 2             1       1  ...  Not available  Not available
# 3             1       1  ...  Not available  Not available
# 4             1       1  ...  Not available  Not available
# ...         ...     ...  ...            ...            ...
# 20538        88       1  ...  Not available  Not available
# 20539        88       1  ...  Not available  Not available
# 20540        88       1  ...  Not available  Not available
# 20541        88       1  ...  Not available  Not available
# 20542        88       1  ...  Not available  Not available
#
# [20543 rows x 21 columns]

# %% [markdown]
# **CORRELATION**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
corrMatrix=ipl.corr()
corrMatrix
# Out:
#                match_id    inning  ...  extra_runs  total_runs
# match_id       1.000000 -0.005654  ...    0.021117   -0.019106
# inning        -0.005654  1.000000  ...    0.008786    0.006178
# over          -0.014638 -0.063630  ...   -0.009572    0.067681
# ball           0.001699 -0.002954  ...    0.001826    0.009913
# is_super_over -0.009956  0.107179  ...    0.017546   -0.000643
# wide_runs      0.004896  0.007934  ...    0.711532    0.030749
# bye_runs       0.010877  0.000363  ...    0.328260    0.034860
# legbye_runs    0.016446  0.006856  ...    0.563895    0.029004
# noball_runs    0.019110 -0.009208  ...    0.184193    0.043934
# penalty_runs   0.006074  0.007277  ...    0.100668    0.015607
# batsman_runs  -0.023315  0.004300  ...   -0.146978    0.978317
# extra_runs     0.021117  0.008786  ...    1.000000    0.061074
# total_runs    -0.019106  0.006178  ...    0.061074    1.000000
#
# [13 rows x 13 columns]

# %% [markdown]
# **HEAT GRAPH**

# %%
sns.heatmap(corrMatrix,annot=True)

# %% [markdown]
# **SCATTER BLOCK**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import numpy as np
m=ipl["over"]
n=ipl["bye_runs"]
plt.scatter(m,n)
